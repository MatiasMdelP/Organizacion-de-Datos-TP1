# %%
import datetime as datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
events = pd.read_csv('./datos/events.csv')
events['date']=pd.to_datetime(events['date'])
events['weekday']=events['date'].apply(lambda x: x.day_name())
events['hour']=events['date'].dt.hour
events['month']=events['date'].dt.month
events['day']=events['date'].dt.day
# Out:
# /home/nicolas/.local/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2714: DtypeWarning: Columns (12,18,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
events.describe()
# Out:
#            event_id      ref_type      ref_hash  application_id  \
# count  2.494423e+06  2.494423e+06  2.494423e+06    2.494423e+06
# mean   9.970445e+01  1.794164e+18  4.641486e+18    9.910934e+01
# std    1.070903e+02  1.707944e+17  2.660724e+18    5.780986e+01
# min    0.000000e+00  1.494519e+18  1.633675e+14    0.000000e+00
# 25%    2.200000e+01  1.891515e+18  2.326142e+18    6.300000e+01
# 50%    3.100000e+01  1.891515e+18  4.688964e+18    6.600000e+01
# 75%    1.610000e+02  1.891515e+18  6.927594e+18    1.450000e+02
# max    7.120000e+02  1.891515e+18  9.223316e+18    3.220000e+02
#
#        device_countrycode  device_os_version  device_brand  device_model  \
# count        2.494423e+06       1.022066e+06  1.164963e+06  2.406456e+06
# mean         6.333597e+18       4.986001e+18  1.633891e+18  4.478847e+18
# std          1.024000e+03       2.394834e+18  1.626674e+18  2.718014e+18
# min          6.333597e+18       1.004084e+16  7.949737e+16  9.530216e+14
# ...

# %%
events.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2494423 entries, 0 to 2494422
# Data columns (total 26 columns):
# date                  datetime64[ns]
# event_id              int64
# ref_type              int64
# ref_hash              int64
# application_id        int64
# attributed            bool
# device_countrycode    int64
# device_os_version     float64
# device_brand          float64
# device_model          float64
# device_city           float64
# session_user_agent    float64
# trans_id              object
# user_agent            float64
# event_uuid            object
# carrier               float64
# kind                  float64
# device_os             float64
# wifi                  object
# connection_type       object
# ip_address            int64
# device_language       float64
# weekday               object
# hour                  int64
# month                 int64
# day                   int64
# ...

# %%
events
# Out:
#                            date  event_id             ref_type  \
# 0       2019-03-05 00:09:36.966         0  1891515180541284343
# 1       2019-03-05 00:09:38.920         1  1891515180541284343
# 2       2019-03-05 00:09:26.195         0  1891515180541284343
# 3       2019-03-05 00:09:31.107         2  1891515180541284343
# 4       2019-03-09 21:00:36.585         3  1891515180541284343
# 5       2019-03-09 20:29:45.449         4  1891515180541284343
# 6       2019-03-09 20:29:40.602         5  1891515180541284343
# 7       2019-03-09 20:45:12.067         0  1891515180541284343
# 8       2019-03-09 20:40:07.977         0  1891515180541284343
# 9       2019-03-09 20:27:09.984         1  1891515180541284343
# 10      2019-03-09 20:27:12.583         0  1891515180541284343
# 11      2019-03-09 20:37:46.087         4  1891515180541284343
# 12      2019-03-09 20:39:54.306         5  1891515180541284343
# 13      2019-03-09 20:53:54.261         6  1891515180541284343
# ...

# %% [markdown]
# ##TEMPORAL

# %%
events['weekday'].value_counts().head(10).plot(kind='bar',figsize=(15,5),fontsize=14,rot=0)
plt.title('Eventos segun dia de la semana')
plt.ylabel("Eventos", size=15)
plt.xlabel("Dia", size=15)
plt.show()

# %%
events['hour'].value_counts(sort=False).plot(kind='line',figsize=(15,5),fontsize=14,rot=90)
plt.title('Eventos segun Hora')
plt.ylabel("Eventos", size=15)
plt.xlabel("Hora", size=15)
plt.show()

# %%
events['day'].value_counts(sort=False).plot(kind='line',figsize=(15,5),fontsize=14,rot=90)
plt.title('Eventos segun Dia')
plt.ylabel("Eventos", size=15)
plt.xlabel("Dia", size=15)
plt.show()

# %% [markdown]
# ##TIPO DE EVENTO

# %%
events['event_id'].value_counts().head(10).plot(kind='bar',figsize=(15,5),fontsize=14,rot=90)
plt.title('Eventos segun event_id')
plt.ylabel("Eventos", size=15)
plt.xlabel("Event ID", size=15)
plt.show()

# %%
events.loc[(events['event_id']==22)|(events['event_id']==31)|(events['event_id']==161)|(events['event_id']==1)|(events['event_id']==138)|(events['event_id']==31)|(events['event_id']==31)].groupby(['hour','event_id'])['hour'].count().unstack().plot(kind='line',figsize=(20,10),fontsize=12)
plt.title('Eventos segun tipo y hora')
plt.ylabel("Cantidad de Eventos", size=15)
plt.xlabel("Horario", size=15)
plt.show()

# %%
events['kind'].value_counts(sort=True).head(10).plot(kind='bar',figsize=(15,5),fontsize=14,rot=90)
plt.title('Eventos segun Kind')
plt.ylabel("Eventos", size=15)
plt.xlabel("Kind", size=15)
plt.show()

# %%
events['user_agent'].value_counts(sort=True).head(10).plot(kind='bar',figsize=(15,5),fontsize=14,rot=90)
plt.title('Eventos segun User Agent')
plt.ylabel("Eventos", size=15)
plt.xlabel("User Agent", size=15)
plt.show()

# %%
events['application_id'].value_counts(sort=True).head(10).plot(kind='bar',figsize=(15,5),fontsize=14,rot=90)
plt.title('Eventos segun application ID')
plt.ylabel("Eventos", size=15)
plt.xlabel("App ID", size=15)
plt.show()

# %% [markdown]
# ##GEOGRAFIA

# %%
events['device_countrycode'].value_counts(sort=True).head(10).plot(kind='bar',figsize=(15,5),fontsize=14,rot=90)
plt.title('Eventos segun Pais')
plt.ylabel("Eventos", size=15)
plt.xlabel("Pais", size=15)
plt.show()

# %%
events['device_city'].value_counts(sort=True).head(10).plot(kind='bar',figsize=(15,5),fontsize=14,rot=90)
plt.title('Eventos segun Ciudad')
plt.ylabel("Eventos", size=15)
plt.xlabel("Ciudad", size=15)
plt.show()

# %% [markdown]
# ##DISPOSITIVO

# %%
events['device_brand'].value_counts().head(10).plot(kind='bar',figsize=(15,5),fontsize=14,rot=90)
plt.title('Eventos segun marca de dispositivo')
plt.ylabel("Eventos", size=15)
plt.xlabel("Marca", size=15)
plt.show()

# %%
events['device_model'].value_counts(sort=True).head(10).plot(kind='bar',figsize=(15,5),fontsize=14,rot=90)
plt.title('Eventos segun modelo')
plt.ylabel("Eventos", size=15)
plt.xlabel("Device Model", size=15)
plt.show()

# %%
events['device_language'].value_counts(sort=True).head(10).plot(kind='bar',figsize=(15,5),fontsize=14,rot=90)
plt.title('Eventos segun Lenguaje de dispositivo')
plt.ylabel("Eventos", size=15)
plt.xlabel("Device Language", size=15)
plt.show()

# %% [markdown]
# ##CONEXION

# %%
events['carrier'].value_counts(sort=True).head(10).plot(kind='bar',figsize=(15,5),fontsize=14,rot=90)
plt.title('Eventos segun Carrier')
plt.ylabel("Eventos", size=15)
plt.xlabel("Carrier", size=15)
plt.show()

# %%
events['wifi'].value_counts(sort=True).head(10).plot(kind='bar',figsize=(15,5),fontsize=14,rot=90)
plt.title('Eventos segun Wifi')
plt.ylabel("Eventos", size=15)
plt.xlabel("Wifi", size=15)
plt.show()

# %%
events.groupby(['hour','wifi'])['hour'].count().unstack().plot(kind='bar',figsize=(20,10),fontsize=12)
plt.title('Eventos segun wifi/hora')
plt.ylabel("Cantidad de Eventos", size=15)
plt.xlabel("Horario", size=15)
plt.show()

# %%
events['connection_type'].value_counts(sort=True).head(10).plot(kind='bar',figsize=(15,5),fontsize=14,rot=90)
plt.title('Eventos segun tipo de conexion')
plt.ylabel("Eventos", size=15)
plt.xlabel("Tipo de conexion", size=15)
plt.show()

# %%
events.loc[(events['connection_type']=='Cable/DSL')|(events['connection_type']=='Cellular')].groupby(['hour','connection_type'])['hour'].count().unstack().plot(kind='bar',figsize=(20,10),fontsize=12)
plt.title('Eventos segun wifi/hora')
plt.ylabel("Cantidad de Eventos", size=15)
plt.xlabel("Horario", size=15)
plt.show()

# %%
events['ip_address'].value_counts(sort=True).head(10).plot(kind='bar',figsize=(15,5),fontsize=14,rot=90)
plt.title('Eventos segun IP')
plt.ylabel("Eventos", size=15)
plt.xlabel("Ip Address", size=15)
plt.show()

# %%
events['carrier'].value_counts(sort=True)
# Out:
# 2.248157e+17    436983
# 1.179587e+18     80958
# 7.855224e+18     58478
# 6.948828e+18     29574
# 3.570805e+18      3457
# 4.890489e+18      2527
# 7.232922e+18      1491
# 7.216102e+18       539
# 1.757690e+18       464
# 3.134984e+18       336
# 2.586833e+18       311
# 8.005034e+18       227
# 2.276828e+17       185
# 3.751135e+18       145
# 5.851846e+18       121
# 1.401083e+18        73
# 3.550680e+18        66
# 5.255184e+18        58
# 5.926614e+18        36
# 6.046847e+18        33
# 2.198851e+18        29
# 4.699500e+18        17
# 1.832902e+18        17
# 1.312636e+18        15
# 7.874982e+18        15
# 4.958858e+17        15
# 5.268426e+18        14
# 8.628827e+18        14
# 5.062450e+17        14
# 2.580401e+18        14
#                  ...
# 5.456621e+18         3
# 2.748831e+18         2
# 3.088861e+18         2
# 8.853016e+18         2
# 3.842293e+18         2
# 5.543220e+18         2
# 2.959658e+18         2
# 4.036081e+18         2
# 2.355114e+18         2
# ...
