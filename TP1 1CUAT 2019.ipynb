# %%
import datetime as datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
events = pd.read_csv('./datos/events.csv')
events['date']=pd.to_datetime(events['date'])
events['weekday']=events['date'].apply(lambda x: x.day_name())
events['hour']=events['date'].dt.hour
events['month']=events['date'].dt.month
events['day']=events['date'].dt.day

# %%
events.describe()
# Out:
#            event_id      ref_type      ref_hash  application_id  \
# count  2.494423e+06  2.494423e+06  2.494423e+06    2.494423e+06
# mean   9.970445e+01  1.794164e+18  4.641486e+18    9.910934e+01
# std    1.070903e+02  1.707944e+17  2.660724e+18    5.780986e+01
# min    0.000000e+00  1.494519e+18  1.633675e+14    0.000000e+00
# 25%    2.200000e+01  1.891515e+18  2.326142e+18    6.300000e+01
# 50%    3.100000e+01  1.891515e+18  4.688964e+18    6.600000e+01
# 75%    1.610000e+02  1.891515e+18  6.927594e+18    1.450000e+02
# max    7.120000e+02  1.891515e+18  9.223316e+18    3.220000e+02
#
#        device_countrycode  device_os_version  device_brand  device_model  \
# count        2.494423e+06       1.022066e+06  1.164963e+06  2.406456e+06
# mean         6.333597e+18       4.986001e+18  1.633891e+18  4.478847e+18
# std          1.024000e+03       2.394834e+18  1.626674e+18  2.718014e+18
# min          6.333597e+18       1.004084e+16  7.949737e+16  9.530216e+14
# ...

# %%
events.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2494423 entries, 0 to 2494422
# Data columns (total 26 columns):
# date                  datetime64[ns]
# event_id              int64
# ref_type              int64
# ref_hash              int64
# application_id        int64
# attributed            bool
# device_countrycode    int64
# device_os_version     float64
# device_brand          float64
# device_model          float64
# device_city           float64
# session_user_agent    float64
# trans_id              object
# user_agent            float64
# event_uuid            object
# carrier               float64
# kind                  float64
# device_os             float64
# wifi                  object
# connection_type       object
# ip_address            int64
# device_language       float64
# weekday               object
# hour                  int64
# month                 int64
# day                   int64
# ...

# %%
events['event_id'].value_counts()
# Out:
# 22     618228
# 31     417070
# 161    217846
# 1      157812
# 138    100039
# 162     84898
# 329     56490
# 156     53332
# 33      48581
# 171     43942
# 310     42101
# 155     38465
# 273     37056
# 23      35588
# 21      26228
# 98      24301
# 158     23738
# 272     22788
# 80      22076
# 50      20905
# 81      18622
# 346     14408
# 58      13940
# 51      13455
# 513     12682
# 354     11711
# 133     11074
# 256     10939
# 274     10035
# 60       9456
#         ...
# 500         1
# 511         1
# 532         1
# 516         1
# 132         1
# 520         1
# 521         1
# 523         1
# 575         1
# 577         1
# 578         1
# 579         1
# 608         1
# 433         1
# 597         1
# 436         1
# 589         1
# 588         1
# 587         1
# 586         1
# 585         1
# 140         1
# 583         1
# 581         1
# 580         1
# 437         1
# 443         1
# 227         1
# 226         1
# 584         1
# ...

# %%
events['user_agent'].value_counts()
# Out:
# 2.394269e+18    42325
# 7.720270e+18    37523
# 6.593868e+18    36173
# 5.930547e+18    35950
# 5.254247e+18    32902
# 6.105227e+18    31554
# 3.437497e+18    28317
# 7.738334e+18    27218
# 4.392265e+18    23386
# 2.948343e+18    19773
# 6.741680e+18    19404
# 5.323195e+18    18277
# 8.234146e+18    17985
# 4.185912e+18    17157
# 1.244062e+18    16243
# 6.840860e+18    15798
# 1.637986e+18    15196
# 2.495805e+18    15085
# 9.177081e+18    14872
# 2.955494e+18    13923
# 5.144382e+18    13033
# 5.407282e+18    11255
# 3.590748e+18    10571
# 8.089178e+18    10551
# 8.227345e+18    10066
# 6.322453e+18     9284
# 8.301990e+17     9100
# 4.472077e+18     8390
# 2.679531e+18     8253
# 5.099011e+17     8160
#                 ...
# 6.861754e+18        1
# 4.671529e+18        1
# 7.074160e+18        1
# 4.192471e+18        1
# 7.092726e+18        1
# 9.123865e+18        1
# 6.809828e+18        1
# 8.019217e+18        1
# 5.183870e+18        1
# 6.444960e+18        1
# ...

# %%
events
# Out:
#                            date  event_id             ref_type  \
# 0       2019-03-05 00:09:36.966         0  1891515180541284343
# 1       2019-03-05 00:09:38.920         1  1891515180541284343
# 2       2019-03-05 00:09:26.195         0  1891515180541284343
# 3       2019-03-05 00:09:31.107         2  1891515180541284343
# 4       2019-03-09 21:00:36.585         3  1891515180541284343
# 5       2019-03-09 20:29:45.449         4  1891515180541284343
# 6       2019-03-09 20:29:40.602         5  1891515180541284343
# 7       2019-03-09 20:45:12.067         0  1891515180541284343
# 8       2019-03-09 20:40:07.977         0  1891515180541284343
# 9       2019-03-09 20:27:09.984         1  1891515180541284343
# 10      2019-03-09 20:27:12.583         0  1891515180541284343
# 11      2019-03-09 20:37:46.087         4  1891515180541284343
# 12      2019-03-09 20:39:54.306         5  1891515180541284343
# 13      2019-03-09 20:53:54.261         6  1891515180541284343
# ...

# %%
events['day'].value_counts().head(10).plot(kind='bar',figsize=(15,5),fontsize=14,rot=0)
plt.title('Eventos segun dia')
plt.ylabel("Eventos", size=15)
plt.xlabel("Dia", size=15)
plt.show()

# %%
events['weekday'].value_counts().head(10).plot(kind='bar',figsize=(15,5),fontsize=14,rot=0)
plt.title('Eventos segun dia de la semana')
plt.ylabel("Eventos", size=15)
plt.xlabel("Dia", size=15)
plt.show()

# %%
events2=events[['date','event_id','ref_hash','attributed','trans_id','event_uuid','wifi','connection_type','weekday','hour','month','day']]

# %%
events['event_id'].value_counts().head(10).plot(kind='bar',figsize=(15,5),fontsize=14,rot=90)
plt.title('Eventos segun event_id')
plt.ylabel("Eventos", size=15)
plt.xlabel("Event ID", size=15)
plt.show()

# %%
events['event_uuid'].value_counts().head(10).plot(kind='bar',figsize=(15,5),fontsize=14,rot=90)
plt.title('Eventos segun event uuid')
plt.ylabel("Eventos", size=15)
plt.xlabel("Event uuid", size=15)
plt.show()

# %%
events['device_brand'].value_counts().head(10).plot(kind='bar',figsize=(15,5),fontsize=14,rot=90)
plt.title('Eventos segun marca de dispositivo')
plt.ylabel("Eventos", size=15)
plt.xlabel("Marca", size=15)
plt.show()

# %%
events['hour'].value_counts(sort=False).plot(kind='line',figsize=(15,5),fontsize=14,rot=90)
plt.title('Eventos segun Hora')
plt.ylabel("Eventos", size=15)
plt.xlabel("Hora", size=15)
plt.show()
